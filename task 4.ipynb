# %% [markdown]
# ## author : Ashok kumar
# ## grip task 4 : perform EDA on global terroism
# ### data science and business analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %%
from folium.plugins import MarkerCluster

# %%
ts=pd.read_csv('C:/Users/Ashok/Desktop/intern/Global Terrorism - START data/globalterrorismdb.csv',encoding='latin1')
# Out:
# C:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
ts.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
ts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
ts.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
ts.shape
# Out:
# (181691, 135)

# %%
ts.corr()
# Out:
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear      0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth     0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday       0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended   0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# ...             ...       ...       ...       ...       ...       ...
# nreleased -0.181612 -0.181556 -0.011535  0.001765 -0.192155 -0.044331
# INT_LOG   -0.143600 -0.143601 -0.002302 -0.001540  0.071768  0.069904
# INT_IDEO  -0.133252 -0.133253 -0.002034 -0.001621  0.075147  0.067564
# INT_MISC  -0.077852 -0.077847 -0.002554 -0.002027  0.027335  0.207281
# INT_ANY   -0.175605 -0.175596 -0.006336 -0.001199  0.080767  0.153118
#
#              region  latitude  longitude  specificity  ...  ransomamt  \
# ...

# %% [markdown]
# ## data visualisation
# ### us terror attack and death injuries

# %%
ts.nkillus.plot(kind='line',color='blue',label='number of confirmed fatalities for us',figsize=(20,20),fontsize=20)
ts.nwoundus.plot(color='green',label='number of confirmed non fatal injuries for us',figsize=(20,20),fontsize=20)
plt.legend(loc='upper right')
plt.xlabel('database index',fontsize=20)
plt.ylabel('number of dead or injuries',fontsize=20)
plt.title('confirmed fatalities & non fatal injuries for us')
plt.show()

# %% [markdown]
# ### death and injuries at all time

# %%
ts.plot(kind='scatter',x='nkill',y='nwound',color='red',figsize=(15,15))
plt.xlabel('kill',fontsize=25)
plt.ylabel('wound',fontsize=25)
plt.title('kill-wound scatterplot')
plt.show()

# %% [markdown]
# ### terrorist actions in region wise and year

# %%
us=ts[ts['region']==1]
us.iyear.plot(kind='hist',bins=20,figsize=(20,20),color='black',fontsize=20)
plt.xlabel('year',fontsize=20)
plt.ylabel('frequency',fontsize=20)
plt.title('frequency of us & mexico terrorism action in years')
plt.show()

# %% [markdown]
# ## terrorist attacks of paticular year and locations

# %%
filterYear = ts['iyear'] == 1970

# %%
filterData = ts[filterYear] 
reqFilterData = filterData.loc[:,'city':'longitude'] 
reqFilterData = reqFilterData.dropna() 
reqFilterDataList = reqFilterData.values.tolist()

# %%
map = folium.Map(location = [0, 30], tiles='CartoDB positron', zoom_start=2)
markerCluster = folium.plugins.MarkerCluster().add_to(map)
for point in range(0, len(reqFilterDataList)):
    folium.Marker(location=[reqFilterDataList[point][1],reqFilterDataList[point][2]], popup = reqFilterDataList[point][0]).add_to(markerCluster)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
killData = ts.loc[:,'nkill']
print('Number of people killed by terror attack:', int(sum(killData.dropna())))
# Out:
# Number of people killed by terror attack: 411868

# %% [markdown]
# ## Number of Killed in Terrorist Attacks by Countries

# %%
countryData = ts.loc[:,'country':'country_txt']

countryKillData = pd.concat([countryData, killData], axis=1)

countryKillFormatData = countryKillData.pivot_table(columns='country_txt', values='nkill', aggfunc='sum')
countryKillFormatData
# Out:
# country_txt  Afghanistan  Albania  Algeria  Andorra  Angola  \
# nkill            39384.0     42.0  11066.0      0.0  3043.0
#
# country_txt  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  ...  \
# nkill                        0.0      490.0     37.0       23.0     30.0  ...
#
# country_txt  Vietnam  Wallis and Futuna  West Bank and Gaza Strip  \
# nkill            1.0                0.0                    1500.0
#
# country_txt  West Germany (FRG)  Western Sahara   Yemen  Yugoslavia  Zaire  \
# nkill                      97.0             1.0  8776.0       119.0  324.0
#
# country_txt  Zambia  Zimbabwe
# nkill          70.0     154.0
#
# [1 rows x 205 columns]

# %%
fsize = plt.rcParams["figure.figsize"]
fsize[0]=50
fsize[1]=50
plt.rcParams["figure.figsize"] = fsize

labels = countryKillFormatData.columns.tolist()
labels = labels[:50]
index = np.arange(len(labels))
transpoze = countryKillFormatData.T
values = transpoze.values.tolist()
values = values[:50]
values = [int(i[0]) for i in values] # convert float to int
colors = ['red', 'green', 'blue', 'purple', 'yellow', 'brown', 'black', 'gray', 'magenta', 'orange'] # color list for bar chart bar color 
fig, ax = plt.subplots(1, 1)
ax.yaxis.grid(True)
fsize = plt.rcParams["figure.figsize"]
fsize[0]=50
fsize[1]=50
plt.rcParams["figure.figsize"] = fig_size
plt.bar(index, values, color = colors, width = 0.9)
plt.ylabel('Killed People', fontsize=15)
plt.xticks(index, labels, fontsize=12, rotation=90)
plt.title('Number of people killed by countries')
plt.show()

# %%
fsize = plt.rcParams["figure.figsize"]
fsize[0]=50
fsize[1]=50
plt.rcParams["figure.figsize"] = fsize

labels = countryKillFormatData.columns.tolist()
labels = labels[51:100]
index = np.arange(len(labels))
transpoze = countryKillFormatData.T
values = transpoze.values.tolist()
values = values[51:100]
values = [int(i[0]) for i in values] # convert float to int
colors = ['red', 'green', 'blue', 'purple', 'yellow', 'brown', 'black', 'gray', 'magenta', 'orange'] # color list for bar chart bar color 
fig, ax = plt.subplots(1, 1)
ax.yaxis.grid(True)
fsize = plt.rcParams["figure.figsize"]
fsize[0]=50
fsize[1]=50
plt.rcParams["figure.figsize"] = fig_size
plt.bar(index, values, color = colors, width = 0.9)
plt.ylabel('Killed People', fontsize=15)
plt.xticks(index, labels, fontsize=12, rotation=90)
plt.title('Number of people killed by countries')
plt.show()

# %%
fsize = plt.rcParams["figure.figsize"]
fsize[0]=50
fsize[1]=50
plt.rcParams["figure.figsize"] = fsize

labels = countryKillFormatData.columns.tolist()
labels = labels[101:205]
index = np.arange(len(labels))
transpoze = countryKillFormatData.T
values = transpoze.values.tolist()
values = values[101:205]
values = [int(i[0]) for i in values] # convert float to int
colors = ['red', 'green', 'blue', 'purple', 'yellow', 'brown', 'black', 'gray', 'magenta', 'orange'] # color list for bar chart bar color 
fig, ax = plt.subplots(1, 1)
ax.yaxis.grid(True)
fsize = plt.rcParams["figure.figsize"]
fsize[0]=50
fsize[1]=50
plt.rcParams["figure.figsize"] = fig_size
plt.bar(index, values, color = colors, width = 0.9)
plt.ylabel('Killed People', fontsize=15)
plt.xticks(index, labels, fontsize=12, rotation=90)
plt.title('Number of people killed by countries')
plt.show()
